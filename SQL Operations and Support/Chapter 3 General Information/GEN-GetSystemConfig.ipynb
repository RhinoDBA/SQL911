-- %% [markdown]
-- Get System Configuration information

-- %%
SET NOCOUNT ON;
SET ANSI_WARNINGS ON;
SET QUOTED_IDENTIFIER ON;

SELECT 'Information' AS [Category], 'All_System_Configurations' AS [Information],
	name AS [Name],
	configuration_id AS [Number],
	minimum AS [Minimum],
	maximum AS [Maximum],
	is_dynamic AS [Dynamic],
	is_advanced AS [Advanced],
	value AS [ConfigValue],
	value_in_use AS [RunValue],
	description AS [Description]
FROM sys.configurations (NOLOCK)
ORDER BY name OPTION (RECOMPILE);
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.090
-- <table><tr><th>Category</th><th>Information</th><th>Name</th><th>Number</th><th>Minimum</th><th>Maximum</th><th>Dynamic</th><th>Advanced</th><th>ConfigValue</th><th>RunValue</th><th>Description</th></tr><tr><td>Information</td><td>All_System_Configurations</td><td>access check cache bucket count</td><td>1582</td><td>0</td><td>65536</td><td>1</td><td>1</td><td>0</td><td>0</td><td>Default hash bucket count for the access check result security cache</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>access check cache quota</td><td>1583</td><td>0</td><td>2147483647</td><td>1</td><td>1</td><td>0</td><td>0</td><td>Default quota for the access check result security cache</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>Ad Hoc Distributed Queries</td><td>16391</td><td>0</td><td>1</td><td>1</td><td>1</td><td>0</td><td>0</td><td>Enable or disable Ad Hoc Distributed Queries</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>ADR cleaner retry timeout (min)</td><td>1591</td><td>0</td><td>32767</td><td>1</td><td>1</td><td>120</td><td>120</td><td>ADR cleaner retry timeout.</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>ADR Preallocation Factor</td><td>1592</td><td>0</td><td>32767</td><td>1</td><td>1</td><td>4</td><td>4</td><td>ADR Preallocation Factor.</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>affinity I/O mask</td><td>1550</td><td>-2147483648</td><td>2147483647</td><td>0</td><td>1</td><td>0</td><td>0</td><td>affinity I/O mask</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>affinity mask</td><td>1535</td><td>-2147483648</td><td>2147483647</td><td>1</td><td>1</td><td>0</td><td>0</td><td>affinity mask</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>affinity64 I/O mask</td><td>1551</td><td>-2147483648</td><td>2147483647</td><td>0</td><td>1</td><td>0</td><td>0</td><td>affinity64 I/O mask</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>affinity64 mask</td><td>1549</td><td>-2147483648</td><td>2147483647</td><td>1</td><td>1</td><td>0</td><td>0</td><td>affinity64 mask</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>Agent XPs</td><td>16384</td><td>0</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>Enable or disable Agent XPs</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>allow filesystem enumeration</td><td>16398</td><td>0</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>Allow enumeration of filesystem</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>allow polybase export</td><td>16397</td><td>0</td><td>1</td><td>1</td><td>0</td><td>0</td><td>0</td><td>Allow INSERT into a Hadoop external table</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>allow updates</td><td>102</td><td>0</td><td>1</td><td>1</td><td>0</td><td>0</td><td>0</td><td>Allow updates to system tables</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>automatic soft-NUMA disabled</td><td>1585</td><td>0</td><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>Automatic soft-NUMA is enabled by default</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>backup checksum default</td><td>1584</td><td>0</td><td>1</td><td>1</td><td>0</td><td>0</td><td>0</td><td>Enable checksum of backups by default</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>backup compression default</td><td>1579</td><td>0</td><td>1</td><td>1</td><td>0</td><td>0</td><td>0</td><td>Enable compression of backups by default</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>blocked process threshold (s)</td><td>1569</td><td>0</td><td>86400</td><td>1</td><td>1</td><td>0</td><td>0</td><td>Blocked process reporting threshold</td></tr><tr><td>Information</td><td>All_System_Configurations</td><td>c2 audit mode</td><td>544</td><td>0</td><td>1</td><td>0</td><td>1</ ...
